# %% [markdown]
# # Optical Character Recognition (ORC)

# %% [markdown]
#  Character detector which extracts printed or handwritten text from an image

# %% [markdown]
# ## Install Tesseract
#
# For windows user, go to this link: https://tesseract-ocr.github.io/tessdoc/4.0-with-LSTM.html#400-alpha-for-windows
#
# Then look for '4.X for Windows' section and click on 'Windows Installer made with MinGW-w64' to download tesseract.
#
# After that install the downloaded file, and locate its directory. Look for the 'tesseract.exe' file and get its path, mine is:
#
# C:\Program Files\Tesseract-OCR\tesseract.exe

# %% [markdown]
# Install pip install pytesseract & pip install opencv-python from cmd prompt for import required libraries

# %% [markdown]
# ## Import Libraries

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
# Copy the 'tesseract.exe' path. Make sure you use double slash \\ instead of single \
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %% [markdown]
# ## Pytesseract for Printed Image OCR

# %%
# Import image
img = cv2.imread('ocrimage.PNG')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(img)

# %%
# Detect and print words contained in the image
print(pytesseract.image_to_string(img))
# Out:
# Here is an image with text.
# Congratulations!
# You have successfully
# Used OCR to read the text

# %%
# Bounding box for word
# By printing this, you get the x,y,w,h coordinates of the boxes
print(pytesseract.image_to_boxes(img))
# Out:
# H 47 167 69 193 0
# e 64 167 78 193 0
# r 72 167 92 186 0
# e 95 167 128 186 0
# i 139 167 144 193 0
# s 147 167 163 186 0
# a 173 167 192 186 0
# n 195 167 213 186 0
# i 226 167 231 193 0
# m 235 167 264 186 0
# a 267 167 286 186 0
# g 281 159 299 193 0
# e 288 159 331 186 0
# w 340 167 355 193 0
# i 340 167 370 186 0
# t 372 167 377 193 0
# h 380 167 413 193 0
# t 424 167 437 192 0
# e 438 167 458 186 0
# x 452 167 467 192 0
# t 459 167 478 186 0
# . 479 167 498 192 0
# C 128 125 152 151 0
# o 153 125 173 144 0
# n 176 125 194 144 0
# g 187 117 205 151 0
# r 197 117 217 144 0
# a 221 125 232 144 0
# t 233 125 252 144 0
# u 254 125 267 150 0
# l 269 125 288 144 0
# a 291 125 301 151 0
# t 302 125 320 144 0
# i 322 125 342 151 0
# o 345 125 365 144 0
# n 368 125 386 144 0
# s 379 117 397 151 0
# ! 389 125 414 151 0
# Y 80 82 103 108 0
# o 104 82 124 101 0
# u 127 82 146 101 0
# h 158 82 176 108 0
# a 179 82 197 101 0
# v 190 82 209 108 0
# e 199 82 239 101 0
# s 249 82 266 101 0
# ...

# %%
# Draw bounding boxes

# Import image
img = cv2.imread('ocrimage.PNG')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

h_img, w_img, no_channel = img.shape
boxes = pytesseract.image_to_boxes(img)

for b in boxes.splitlines():
    #print(b)
    b = b.split(' ')
    #print(b)
    x,y,w,h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
    cv2.rectangle(img, (x, h_img-y), (w,h_img-h), (255,0,0), 1)
    cv2.putText(img, b[0], (x, h_img-y+10), cv2.FONT_HERSHEY_COMPLEX,0.4, (0,0,0),1)

#plt.clf()
plt.figure(figsize = (20,10))
plt.imshow(img)

# %% [markdown]
# ## Pytesseract for Handwritten Image OCR

# %%
# Import image
img = cv2.imread('sampleocr.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(img)

# %%
# Detect and print words contained in the image
print(pytesseract.image_to_string(img))
# Out:
# This is a handwritten
# example
#
# Write as qooal as you can.

# %% [markdown]
# # Thank you!!
#
# #### Moumita Das
